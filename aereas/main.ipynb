# %%
# Importando o as bilbiotecas
import pandas as pd

# %%
df = pd.read_csv("ocorrencias_aereas.csv", sep=";")
df.head(2)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              52242               52242               52242
# 1              45331               45331               45331
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               52242               52242                INCIDENTE
# 1               45331               45331                 ACIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                 NaN                  NaN      PORTO ALEGRE            RS
# 1      -23.4355555556       -46.4730555556         GUARULHOS            SP
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  ...     05/01/2012        20:27:00                            ***
# 1  ...     06/01/2012        13:44:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5167 entries, 0 to 5166
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   codigo_ocorrencia               5167 non-null   int64
#  1   codigo_ocorrencia1              5167 non-null   int64
#  2   codigo_ocorrencia2              5167 non-null   int64
#  3   codigo_ocorrencia3              5167 non-null   int64
#  4   codigo_ocorrencia4              5167 non-null   int64
#  5   ocorrencia_classificacao        5167 non-null   object
#  6   ocorrencia_latitude             4192 non-null   object
#  7   ocorrencia_longitude            4192 non-null   object
#  8   ocorrencia_cidade               5167 non-null   object
#  9   ocorrencia_uf                   5167 non-null   object
#  10  ocorrencia_pais                 5167 non-null   object
#  11  ocorrencia_aerodromo            5167 non-null   object
# ...

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'GUARULHOS'

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1              45331               45331               45331
# 2              45333               45333               45333
# 3              45401               45401               45401
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 1               45331               45331                 ACIDENTE
# 2               45333               45333                 ACIDENTE
# 3               45401               45401                 ACIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 1      -23.4355555556       -46.4730555556         GUARULHOS            SP
# 2                 ***                  ***            VIAMÃO            RS
# 3                 ***                  ***     SÃO SEBASTIÃO            SP
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 1  ...     06/01/2012        13:44:00                            SIM
# ...

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 10              45332               45332               45332
# 40              45415               45415               45415
#
#     codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 10               45332               45332                 ACIDENTE
# 40               45415               45415                 ACIDENTE
#
#    ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 10                 ***                  ***            VIAMÃO            RS
# 40                 ***                  ***    RIO DE JANEIRO            RJ
#
#     ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 10  ...     09/01/2012        13:30:00                            SIM
# 40  ...     30/01/2012        13:55:00                            SIM
#
#    investigacao_status divulgacao_relatorio_numero  \
# 10          FINALIZADA           A-072/CENIPA/2013
# ...

# %% [markdown]
# Selecionando todas as linhas de umas determinadas colunas

# %%
df.loc[:,['ocorrencia_cidade', 'ocorrencia_uf']]
# Out:
#      ocorrencia_cidade ocorrencia_uf
# 0         PORTO ALEGRE            RS
# 1            GUARULHOS            SP
# 2               VIAMÃO            RS
# 3        SÃO SEBASTIÃO            SP
# 4             SÃO SEPÉ            RS
# ...                ...           ...
# 5162             JATAÍ            GO
# 5163           MARACAÍ            SP
# 5164     NOVO HAMBURGO            RS
# 5165          CURITIBA            PR
# 5166         PETROLINA            PE
#
# [5167 rows x 2 columns]

# %% [markdown]
# Definindo o indice da tabela

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
# Exibindo os títulos das colunas
df.head()
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 52242                           52242               52242               52242
# 45331                           45331               45331               45331
# 45333                           45333               45333               45333
# 45401                           45401               45401               45401
# 45407                           45407               45407               45407
#
#                    codigo_ocorrencia4 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
#
# ...

# %%
# Reseta o indice da tabela
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               52242               52242               52242
# 1               45331               45331               45331
# 2               45333               45333               45333
# 3               45401               45401               45401
# 4               45407               45407               45407
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               52242                INCIDENTE                 NaN
# 1               45331                 ACIDENTE      -23.4355555556
# 2               45333                 ACIDENTE                 ***
# 3               45401                 ACIDENTE                 ***
# 4               45407                 ACIDENTE                 ***
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  NaN      PORTO ALEGRE            RS          BRASIL  ...
# ...

# %%
# Altera todos os dados de uma linha
df.loc[0, 'ocorrencia_aerodromo'] = ''

# %%
# Altera todos os valores de uma coluna
df.loc[:, 'codigo_ocorrencia4'] = 123

# %%
# Criar um backup de uma coluna
df['ocorrencia_cidade_bkp'] = df.ocorrencia_cidade

# %%
# Fazendo um filtro
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 1                  45331               45331               45331
# 3                  45401               45401               45401
# 5                  52243               52243               52243
# 6                  50713               50713               50713
# 13                 45408               45408               45408
# ...                  ...                 ...                 ...
# 5148               80441               80441               80441
# 5157               80453               80453               80453
# 5158               80454               80454               80454
# 5161               80456               80456               80456
# 5163               80452               80452               80452
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 1                    123                 ACIDENTE      -23.4355555556
# ...

# %%
# Fazendo um filtro utilizando AND
#df.loc[df.ocorrencia_classificacao == 'INCIDENTE']

df.loc[(df.ocorrencia_uf == 'SP') & (df.ocorrencia_classificacao == 'INCIDENTE')]
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 5                  52243               52243               52243
# 28                 52248               52248               52248
# 35                 52054               52054               52054
# 36                 52055               52055               52055
# 53                 45469               45469               45469
# ...                  ...                 ...                 ...
# 5129               80433               80433               80433
# 5134               80425               80425               80425
# 5143               80431               80431               80431
# 5157               80453               80453               80453
# 5161               80456               80456               80456
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 5                    123                INCIDENTE                 NaN
# ...

# %% [markdown]
# Fazendo a limpeza de dados

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude                975
# ocorrencia_longitude               975
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo                 0
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada     166
# investigacao_status                257
# divulgacao_relatorio_numero        384
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         3816
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# ocorrencia_cidade_bkp                0
# dtype: int64
